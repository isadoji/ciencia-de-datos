# %% [markdown]
# # Exploración de las atransformaciones de los datos a sqrt, log y box-cox

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd

from scipy.stats import boxcox 
#https://www.kaggle.com/datasets/rakannimer/air-passengers?select=AirPassengers.csv

df = pd.read_csv('../datasets/AirPassengers.csv',  index_col = 'Month', parse_dates=True)
df.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
df['#Passengers'].plot(figsize=(12, 8))
# Out:
# <AxesSubplot: xlabel='Month'>

# %% [markdown]
# ## Características
#
# 1. Creciente
# 2. Sinusoidal creciente (amplitud)

# %%
df['Sqrt_Passengers'] = np.sqrt(df['#Passengers'])
df['Sqrt_Passengers'].plot(figsize=(12, 8))
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
df['Log_Passengers'] = np.log(df['#Passengers'])
df['Log_Passengers'].plot(figsize=(12, 8))
# Out:
# <AxesSubplot: xlabel='Month'>

# %%
df['Boxcox_Passengers'], lam = boxcox(df['#Passengers']) # lam is the lambda value
df['Boxcox_Passengers'].plot(figsize=(12, 8))
# Out:
# <AxesSubplot: xlabel='Month'>

# %% [markdown]
# ## Características
#
# 1. entre sqrt y log

# %%
df['#Passengers'].hist(bins = 20) #mas datos en los valores menores
# Out:
# <AxesSubplot: >

# %%
df['Sqrt_Passengers'].hist(bins = 20) #plana a valores menores
# Out:
# <AxesSubplot: >

# %%
df['Log_Passengers'].hist(bins = 20) # redistribución al centro
# Out:
# <AxesSubplot: >

# %%
df['Boxcox_Passengers'].hist(bins = 20) #mas centrada
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Box-Cox
#
# Transformación de una distribuci{on no-normal a una normal, ajustando $\lambda$

# %%
np.random.seed(0)
data = np.random.exponential(size=1000)
transformed_data, best_lambda = boxcox(data) 
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.hist(data, density=True,bins = 100, histtype = 'step')
plt.subplot(1,2,2)
plt.hist(transformed_data, density=True,bins = 100, histtype = 'step')
plt.show()
