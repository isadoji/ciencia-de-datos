# %% [markdown]
# # Redes neuronales
#
# * La estructura de una red neuronal es mediante el uso de **capas**, formadas a su vez por **neuronas**.
# * Cada neurona, realiza una operación sencilla y está conectada a las neuronas de la capa anterior y de la capa siguiente mediante **pesos**,
# * Los *pesos* regulan la información que se propaga de una neurona a otra.
#
#
# 1. La primera capa de la red neuronal (color rojo) se conoce como capa de entrada y recibe el valor de los predictores *X*.
# 2. La capa intermedia (color azul), recibe los valores de la capa de entrada, ponderados por los pesos *W*.
# 3. La capa de salida (color verde), combina los valores que salen de la capa intermedia para generar la predicción *Y*.

# %% [markdown]
# <center> <div> <img src="fig/red.jpeg" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# * La **neurona** es la unidad funcional de los modelos de redes. Dentro de cada neurona, ocurren simplemente dos operaciones: la suma ponderada de sus entradas y la aplicación de una función de activación.
#
# * En la primera parte, se multiplica cada valor de entrada  $x_i$ por su peso asociado  $w_i$  y se suman junto con el umbral. Este es el valor neto de entrada a la neurona.
# * A continuación, este valor se pasa por una función, conocida como función de activación, que transforma el valor neto de entrada en un valor de salida.
#
# Si bien el valor que llega a la neurona, multiplicación de los pesos por las entradas, siempre es una combinación lineal, gracias a la función de activación, se pueden generar salidas muy diversas. Es en la función de activación donde reside el potencial de los modelos de redes para aprender relaciones no lineales.
#
# El valor neto de entrada a una neurona es la suma de los valores que le llegan, ponderados por el peso de las conexiones, más el sesgo de la función
#
# $
# \begin{equation}
# entrada = \sum_{i = 1}^{n} x_i w_i +b
# \end{equation}
# $
#
# A este valor se le aplica una función de activación (g) que lo transforma en lo que se conoce como valor de activación (a), que es lo que finalmente sale de la neurona.
#
# $
# \begin{equation}
# a = g(entrada) = g(\mathbf{XW}+b)
# \end{equation}
# $
#
# La función activación calcula el estado de actividad de una neurona; transformando la entrada global (menos el umbral) en un valor (estado) de
# activación, cuyo rango normalmente va de (0 a 1) o de (–1 a 1). Esto es así, porque una neurona puede estar totalmente inactiva (0 o –1) o activa (1).

# %% [markdown]
# ## Función de activación
#
# La función activación, es una función de la entrada global ($gin_i$) menos el umbral ($\theta_i$). Las funciones de activación más utilizadas son:
#
# ### 1. Función lineal
#
# ### 2. Función sigmoidea
#
# ### 3. Función tangente hiperbólica
#
# <center> <div> <img src="fig/activ.png" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# ## Función de salida
#
# * La función de salida determina que valor se transfiere a las neuronas vinculadas.
# * Si la función de activación está por debajo de un umbral determinado, ninguna salida se pasa a la neurona subsiguiente. Normalmente, no cualquier valor es permitido como una entrada para una neurona, por lo tanto, los valores de salida están comprendidos en el rango [0, 1] o [-1, 1]. También pueden ser binarios {0, 1} o {-1, 1}.
#
# Las funciones de salida más comunes son:
#
# 1. Función identidad : este es el tipo de función más sencillo, tal que la salida es la misma que la entrada.
# 2. Binaria : 1 si la función de activación es mayor que el umbral y 0 si no.

# %% [markdown]
# ## Función de coste o pérdida
#
# Es la encargada de cuantificar la distancia entre el valor real y el valor predicho por la red. Cuanto más próximo a cero es el valor de coste, mejor son las predicciones de la red (menor error), siendo cero cuando las predicciones se corresponden exactamente con el valor real.
#
# 1. En problemas de regresión, las más utilizadas son el **Error Cuadrático Medio** y el **Error Absoluto Medio**.
# 2. En problemas de clasificación suele emplearse la función **Log Loss**, también llamada **Logistic Loss** o **Cross-Entropy Loss**.

# %% [markdown]
# ## Entrenamiento
#
# El proceso de entrenamiento de una red neuronal consiste en ajustar el valor de los pesos y el umbral de tal forma que, las predicciones que se generen, tengan el menor error posible.
#
# 1. Iniciar la red con valores aleatorios de los pesos y el umbral
#
# 2. Para cada observación de entrenamiento (X,y), calcular el error que comete la red al hacer sus predicciones.
#
# 3. Promediar los errores de todas las observaciones.
#
# 4. Identificar la responsabilidad que ha tenido cada peso y el umbral en el error de la predicción.
#
# 5. Modificar los pesos y el umbral de la red (de forma proporcional a su responsabilidad en el error) en la dirección correcta para que se reduzca el error.
#
# 6. Repetir los pasos 2, 3, 4 y 5 hasta que la red sea suficientemente buena, utilizando el algoritmo de retropropagación (backpropagation) y la optimización por descenso de gradiente (gradient descent).

# %% [markdown]
# ## Backpropagation
#
# Backpropagation es el algoritmo que permite cuantificar la influencia que tiene cada peso y el umbral de la red en sus predicciones. Para conseguirlo, hace uso de la regla de la cadena para calcular el gradiente.
#
# * La derivada parcial del error respecto a un parámetro (umbral) mide cuanta "responsabilidad" ha tenido ese parámetro en el error cometido e identificar qué pesos de la red hay que modificar para mejorarla, utilizando el descenso de gradiente.
#
# ## Descenso de gradiente
#
# Descenso de gradiente (gradient descent) es un algoritmo de optimización que permite minimizar una función haciendo actualizaciones de sus parámetros en la dirección del valor negativo de su gradiente.
#
# Aplicado a las redes neuronales, el descenso de gradiente permite ir actualizando los pesos y sesgo del modelo para reducir su error.

# %% [markdown]
# ## ¿Cómo cambia una red neuronal cuando agregamos neuronas y capas?

# %% [markdown]
# ## Redes neuronales en python
#
# ### Librería Keras
# https://keras.io/
#
# * Es una librería simple y compacta desarrollada por François Chollet, ingeniero de Google.
# * Es una interfaz de alto nivel de otra librería más compleja, TensorFlow.
# * TensorFlow es una librería de código abierto desarrollada por el equipo del proyecto de investigación Google Brain.
#
# ### Librería PyTorch
# https://pytorch.org/
#
# * Desarrollada por el equipo de  Facebook AI Research

# %% [markdown]
# ## Keras
#
# $ conda install tensorflow-gpu
#
# $ conda install pandas matplotlib seaborn scikit-learn  cudatoolkit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

from tensorflow import keras
from sklearn.metrics import accuracy_score

import tensorflow as tf
# Out:
# 2025-01-17 11:22:55.264489: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
print("Versión de tensorflow:{}".format(tf.__version__))
print("GPU:{}".format(tf.test.gpu_device_name()))
# Out:
# Versión de tensorflow:2.17.0
# GPU:

# %%
# Leer el archivo CSV especificando el motor 'python'
df_train = pd.read_csv('./datasets/train_data_n.csv')
df_test = pd.read_csv('./datasets/test_data_n.csv')
df_train.shape, df_test.shape
# Out:
# ((1000, 101), (1000, 101))

# %%
# Separar las columnas de entrada y salida
features_train = df_train.drop('target', axis=1)
target_train = df_train['target']

features_valid= df_test.drop('target', axis=1)
target_valid = df_test['target']

# %% [markdown]
# ## Rede neuronal de una sola capa: Regresión lineal
#
# <center> <div> <img src="fig/rl.png" alt="Drawing" style="width: 500px;"/></div>

# %%
# Regresión lineal
model = LinearRegression()
model.fit(features_train,target_train)
# Out:
# LinearRegression()

# %% [markdown]
# Inicializar la red neuronal que construiremos. Establezcamos la clase del modelo en Sequential. Esta clase se utiliza para modelos con capas secuenciales. Una capa es un conjunto de neuronas que comparten la misma entrada y salida.

# %%
# crea el modelo
from keras.models import Sequential
model = Sequential()

# %% [markdown]
# 1.  La red consistirá en una sola neurona (o el valor en una salida).
# 2. Tiene n entradas, cada una multiplicada por su propio peso. Por ejemplo, x₁
# se multiplica por w₁. Hay una entrada más y siempre es igual a la unidad. Su
# peso se designa como b (sesgo). Lo que constituye el proceso de entrenamiento de la red neuronal es la selección de pesos w y b.
# 3. Después de sumar todos los productos de los valores de las entradas y los
# pesos, la respuesta de la red neuronal (a) se envía a la salida.
#
#
# - **keras.layers.Dense()** crea una capa de neuronas. "Dense" (densa) significa que cada entrada estará conectada a cada neurona o salida.
# - **units** establece la cantidad de neuronas en la capa
# - **input_dim** establece la cantidad de entradas en la capa (este parámetro no considera el sesgo)
#
# Para agregar la capa completamente conectada al modelo, llama al método **model.add()**

# %%
# indica cómo está organizada la red neuronal
model.add(keras.layers.Dense(units=1, input_dim=features_train.shape[1]))
# Out:
# /home/isadoji/Software/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# El modelo es preparado para el entrenamiento.
#
# - Se especifica el ECM como la función de pérdida de la tarea de regresión para el parámetro loss.
# - Se establece el método de descenso de gradiente para el parámetro Optimizer='sgd'.

# %%
# indica cómo está entrenada la red neuronal
model.compile(loss='mean_squared_error', optimizer='sgd')

# %% [markdown]
# Ejecutar el entrenamiento:

# %%
# entrena el modelo
model.fit(features_train, target_train)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.4208

# %% [markdown]
# ### Otros parámetros importantes son:
#
# - **Época (Epoch)**: es una pasada completa a través de todo el conjunto de datos de entrenamiento. Durante una época, el modelo ve cada muestra de datos una vez y ajusta sus pesos en función del error calculado.
# - **Lote (Batch)**: ee es un subconjunto del conjunto de datos de entrenamiento.
# Los datos de entrenamiento se dividen en varios lotes, y el modelo se entrena en cada lote de manera iterativa. El tamaño del lote (batch size) es el número de muestras que se procesan antes de actualizar los pesos del modelo.
# - Una iteración es una pasada a través de un solo lote de datos.
# El número de iteraciones por época es igual al número total de muestras de entrenamiento dividido por el tamaño del lote.
#
# Entrenar el modelo durante múltiples épocas permite que el modelo ajuste sus pesos de manera iterativa y converja hacia una solución óptima.
# 1. Un número insuficiente de épocas puede resultar en un modelo subentrenado (underfitting).
# 2. Un número excesivo de épocas puede llevar a un modelo sobreentrenado (overfitting).
#
# Evaluación del Rendimiento:
#
# Durante el entrenamiento, se evalúa el rendimiento del modelo en el conjunto de validación después de cada época para monitorear el progreso y ajustar los hiperparámetros si es necesario.

# %% [markdown]
# ## Regresión logística

# %%
# 2 categorías
df_train['target'] = (df_train['target'] > df_train['target'].median()).astype(int)
features_train = df_train.drop('target', axis=1)
target_train = df_train['target']

df_test['target'] = (df_test['target'] > df_test['target'].median()).astype(int)
features_valid = df_test.drop('target', axis=1)
target_valid = df_test['target']

# %%
# Keras
# Definir el modelo
model = Sequential()
model.add(keras.layers.Dense(
        units=1, 
        input_dim=features_train.shape[1], 
        activation='sigmoid'
    )
)
model.compile(loss='binary_crossentropy',
              optimizer='sgd', 
              metrics=['acc'])

# Entrenar el modelo
history = model.fit(
    features_train,
    target_train,
    epochs=5,
    verbose=2,
    validation_data=(features_valid, target_valid),
)

# Evaluar el modelo
loss, accuracy = model.evaluate(features_valid, target_valid)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# /home/isadoji/Software/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 - 1s - 18ms/step - acc: 0.4820 - loss: 0.9494 - val_acc: 0.4940 - val_loss: 0.9066
# Epoch 2/5
# 32/32 - 0s - 5ms/step - acc: 0.4920 - loss: 0.9092 - val_acc: 0.5020 - val_loss: 0.8801
# Epoch 3/5
# 32/32 - 0s - 4ms/step - acc: 0.4940 - loss: 0.8726 - val_acc: 0.5050 - val_loss: 0.8564
# Epoch 4/5
# 32/32 - 0s - 4ms/step - acc: 0.5010 - loss: 0.8404 - val_acc: 0.5060 - val_loss: 0.8350
# Epoch 5/5
# 32/32 - 0s - 4ms/step - acc: 0.5140 - loss: 0.8116 - val_acc: 0.5030 - val_loss: 0.8157
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.4986 - loss: 0.8286
# Validation Loss: 0.8157384991645813
# ...

# %% [markdown]
# ## Redes neuronales totalmente conectadas
#
# <center> <div> <img src="fig/nn.png" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# 1. Cada neurona, excepto la última, es seguida por una función de activación.
# <center> <div> <img src="fig/nn1.png" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# Para obtener z, suma todos los productos de los valores de entrada y los pesos:
#
# $
# z1 = x1 * w11 + x2 * w12\\
# z2 = x1 * w21 + x2 * w22\\
# z3 = z1 * w31 + z2 * w32
# $
#
# Tenemos que:
#
# $
# z3 = (x1 * w11 + x2 * w12) * w31 + (w21 * x1 + w22 * x2) * w32
# $
#
# Saca a x₁ y x₂ de los corchetes:
#
# $
# z3 = x1 * (w11 * w31 + w21 * w32) + x2 * (w12 * w31 + w22 * w32)
# $
#
# usaremos una nueva notación, W₁ y W₂:
#
# $
# W_1' = w11 * w31 + w21 * w32 \\
# W_2' = w12 * w31 + w22 * w32
# $
#
# y obtenemos una red multicapa es una red de una sola neurona
#
# $
# z3 = x1 * W_1' + x2 * W_2'
# $
#
# <center> <div> <img src="fig/nn2.png" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# Reinreintroducir el sigmoide
#
# $
# z1 = σ(x1 * w11 + x2 * w12)\\
# z2 = σ(x1 * w21 + x2 * w22)\\
# z3 = z1 * w31 + z2 * w32
# $
#
# Obtenemos:
#
# $
# z3 =  σ(x1 * w11 + x2 * w12) * w31 + σ(w21 * x1 + w22 * x2) * w32
# $
#
# Debido a los sigmoides, no podemos sacar a x₁ y x₂ de los corchetes. Esto significa que ahora no estamos tratando con una sola neurona. Los sigmoides permiten hacer que la red sea más compleja.
#
# <center> <div> <img src="fig/nn3.png" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# - Similar a la regresión lineal, las redes multicapa están entrenadas con un descenso de gradiente.
# - Hay parámetros que son los pesos de las neuronas en cada capa totalmente conectada.
# - El objetivo de entrenamiento es encontrar los parámetros que resultan en la función de pérdida mínima.
#
# A medida que aumenta el número de capas, el entrenamiento se vuelve menos eficiente.
# - Cuantas más capas haya en la red, menos señal habrá de la entrada a la salida de la red. Esto se llama señal de fuga y es causada por el sigmoide, que convierte grandes valores en más pequeños una y otra vez.
# - Para deshacerte del problema puedes intentar otra función de activación, por ejemplo, ReLU (unidad lineal rectificada). ReLU lleva todos los valores negativos a 0 y deja valores positivos sin cambios.
#
#                                     RELu(x)=max(0,x)
#
# <center> <div> <img src="fig/relu.png" alt="Drawing" style="width: 500px;"/></div>

# %% [markdown]
# ## Para jugar con los parámetros:
#
#
# https://playground.tensorflow.org

# %%
model = keras.models.Sequential()
model.add(
    keras.layers.Dense(
        units=10, input_dim=features_train.shape[1], activation='sigmoid'
    )
)
# Se añade una capa oculta
model.add(keras.layers.Dense(units=1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['acc'])
# Entrenar el modelo
history = model.fit(
    features_train,
    target_train,
    epochs=5,
    verbose=2,
    validation_data=(features_valid, target_valid),
)

# Evaluar el modelo
loss, accuracy = model.evaluate(features_valid, target_valid)
print(f'Validation Loss: {loss}')
print(f'Validation Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# /home/isadoji/Software/miniconda3/envs/tf/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 32/32 - 1s - 19ms/step - acc: 0.5030 - loss: 0.7152 - val_acc: 0.5090 - val_loss: 0.7007
# Epoch 2/5
# 32/32 - 0s - 4ms/step - acc: 0.5050 - loss: 0.7124 - val_acc: 0.5170 - val_loss: 0.6993
# Epoch 3/5
# 32/32 - 0s - 4ms/step - acc: 0.5030 - loss: 0.7103 - val_acc: 0.5330 - val_loss: 0.6982
# Epoch 4/5
# 32/32 - 0s - 4ms/step - acc: 0.5070 - loss: 0.7084 - val_acc: 0.5370 - val_loss: 0.6971
# Epoch 5/5
# 32/32 - 0s - 4ms/step - acc: 0.4940 - loss: 0.7068 - val_acc: 0.5420 - val_loss: 0.6964
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - acc: 0.5357 - loss: 0.7021
# Validation Loss: 0.6963922381401062
# ...

# %% [markdown]
# ## MLP
# El Perceptrón Multicapa (MLP) es una red neuronal artificial que se utiliza para el aprendizaje supervisado en el campo del aprendizaje automático

# %%
# SciKit Learn MLP
from sklearn import metrics
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor

mlp = MLPClassifier(hidden_layer_sizes=(8,8,8), 
                    activation='relu', 
                    solver='adam', 
                    max_iter=1000)
mlp.fit(features_train,target_train)

predict_train = mlp.predict(features_train)
predict_test = mlp.predict(features_valid)
cm = metrics.confusion_matrix(target_train,predict_train)

plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, 
            fmt=".3f", 
            linewidths=.5, 
            square = True, 
            cmap = 'Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion matrix', size = 15)

print("Accuracy:",metrics.accuracy_score(target_train, predict_train))
#print(classification_report(features_train,predict_train))
# Out:
# Accuracy: 0.999

# %%
from sklearn.model_selection import RandomizedSearchCV
import multiprocessing


param_distributions = {
    'hidden_layer_sizes': [(10), (10, 10), (20, 20,20)],
    'alpha': np.logspace(-3, 3, 7),
    'learning_rate_init': [0.001, 0.01, 0.1],
}

grid = RandomizedSearchCV(
        estimator  = MLPClassifier(solver = 'lbfgs', max_iter= 1000),
        param_distributions = param_distributions,
        n_iter     = 50, # Número máximo de combinaciones probadas
        scoring    = 'accuracy',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = 3, 
        verbose    = 0,
        random_state = 123,
        return_train_score = True
       )

grid.fit(X = features_train, y = target_train)

# Resultados del grid
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False)\
    .head(10)
# Out:
# /home/isadoji/Software/miniconda3/envs/tf/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/isadoji/Software/miniconda3/envs/tf/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %%
modelo = grid.best_estimator_
modelo
# Out:
# MLPClassifier(alpha=100.0, hidden_layer_sizes=10, learning_rate_init=0.1,
#               max_iter=1000, solver='lbfgs')

# %%
mlp = MLPClassifier(alpha=0.1, hidden_layer_sizes=(10), activation='relu', solver='lbfgs', max_iter=1000)
mlp.fit(features_train,target_train)

predict_test = mlp.predict(features_valid)
predict_train = mlp.predict(features_train)

cm = metrics.confusion_matrix(target_valid,predict_test)

plt.figure(figsize=(5,5))
sns.heatmap(cm, annot=True, 
            fmt=".3f", 
            linewidths=.5, 
            square = True, 
            cmap = 'Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.title('Confusion matrix', size = 15)

print("Accuracy:",metrics.accuracy_score(target_valid, predict_test))
# Out:
# Accuracy: 0.552

# %% [markdown]
# ### Bibliografía
#
# Redes Neuronales: Conceptos Básicos y Aplicaciones. Damián Jorge Matich (2001)
#
# https://cienciadedatos.net/documentos/py35-redes-neuronales-python
